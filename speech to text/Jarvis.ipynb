# %%
from googletrans import Translator
import speech_recognition as sr
from playsound import playsound
from gtts import gTTS
import pywhatkit
import datetime
import pyttsx3
import wikipedia
import pyjokes
import os



engine = pyttsx3.init()
translator = Translator()


voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)
engine.setProperty('rate',160)
engine.setProperty('volume',1)

langu = 'en'

def language():
    talk('Select the language for Your Alexa...')
    try:
        r = sr.Recognizer()
        with sr.Microphone() as source:
            print("listening.....")
            r.pause_threshold = 1
            audio = r.listen(source)
            
        print("Recognizing.....")
        comm = r.recognize_google(audio, language='en-in')
        abc = f"you have selected the {comm} language for your Alexa\n"
        print(abc)
        talk(abc)
        
        
    except Exception as e:
        pass
    
    return comm

def speka():
    playsound("captured_voice.mp3")
    os.remove('captured_voice.mp3')
    return
        
def talk(text,lang=langu):
#     print(langu)
    tr = translator.translate(text,dest=lang)
    speak = gTTS(text=tr.text, lang=lang, slow=False)
    speak.save("captured_voice.mp3")
    speka()
    


def transl():
    comm = language()
    lang = 'mein aapake lie kya kar sakatee hu'
    
    if 'Hindi' in comm:
        hin = translator.translate(lang, dest='hi')
        speak = gTTS(text=hin.text, lang='hi', slow=False)
        speak.save("captured_voice.mp3")
        langu = 'hi'
        speka()
        return langu
        
    elif 'Kannada' in comm:
        kan = translator.translate(lang,dest='kn')
        speak = gTTS(text=kan.text, lang='kn', slow=False)
        speak.save("captured_voice.mp3")
        langu = 'kn'
        speka()
        return langu
        
    elif 'English' in comm:
        eng = translator.translate(lang,dest='en')
        speak = gTTS(text=eng.text, lang='en', slow=False) 
        speak.save("captured_voice.mp3")
        langu = 'en'
        speka()
        return langu
        
    else:
        talk('Please Select Other language...')

    

def take_command():
    try:
        listener = sr.Recognizer()
        with sr.Microphone() as source:
            print('listening...')
            voice = listener.listen(source)
            commnd = listener.recognize_google(voice,language='en')
            commnd = commnd.lower()
            if 'alexa' in commnd:
                commnd = commnd.replace('alexa', '')
                print(commnd)
    except:
        pass
    return commnd

def run_alexa():
    commnd = take_command()
    print(commnd)
    if 'play' in commnd:
        song = commnd.replace('play', '')
        say = 'playing ' + song
        talk(say)
        pywhatkit.playonyt(song)
    elif 'time' in commnd:
        time = datetime.datetime.now().strftime('%I:%M %p')
        talk('Current time is ' + time)
        print(time)
    elif 'who is' in commnd:
        person = commnd.replace('who the heck is', '')
        info = wikipedia.summary(person, 1)
        print(info)
        talk(info)
    elif 'date' in commnd:
        talk('sorry, I know You have a boyfriend')
    elif 'are you single' in commnd:
        talk('No,I am in a relationship with Chetan')
    elif 'joke' in commnd:
        jk = pyjokes.get_joke()
        print(jk)
        talk(jk)
    elif 'lang' in commnd:
        transl()
    else:
        talk('Please say the command again.')



run_alexa()
# Out:
# listening...
# is the language
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 139>()
#     134     else:
#     135         talk('Please say the command again.')
# --> 139 run_alexa()
#
# Input In [5], in run_alexa()
#     131     talk(jk)
#     132 elif 'lang' in commnd:
# --> 133     transl()
#     134 else:
#     135     talk('Please say the command again.')
#
# Input In [5], in transl()
#      62 def transl():
# ---> 63     comm = language()
#      64     lang = 'mein aapake lie kya kar sakatee hu'
#      66     if 'Hindi' in comm:
#
# Input In [5], in language()
#      25 def language():
# ---> 26     talk('Select the language for Your Alexa...')
#      27     try:
#      28         r = sr.Recognizer()
#
# Input In [5], in talk(text, lang)
#      55     tr = translator.translate(text,dest=lang)
#      56 #     speak = gTTS(text=tr.text, lang=lang, slow=False)
#      57 #     speak.save("captured_voice.mp3")
# ---> 58     return speka()
#
# Input In [5], in speka()
#      46 def speka():
# ---> 47     speak = gTTS(text=tr.text, lang=langu, slow=False)
#      48     speak.save("captured_voice.mp3")
#      49     playsound("captured_voice.mp3")
#
# NameError: name 'tr' is not defined
